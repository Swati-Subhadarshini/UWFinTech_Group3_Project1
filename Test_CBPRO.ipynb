# %%
import os
import requests
import pandas as pd

# %%
import cbpro

# %%
c = cbpro.PublicClient()

# %%
Bitcoin = pd.DataFrame(c.get_product_historic_rates('BTC-USD', start = '2021-01-01T01:00:00', end = '2021-10-07T01:00:00' , granularity = 86400))
Bitcoin.columns= ["Date","Open","High","Low","Close","Volume"]
Bitcoin['Date'] = pd.to_datetime(Bitcoin['Date'], unit='s')
Bitcoin.set_index('Date', inplace=True)
Bitcoin.sort_values(by='Date', ascending=True, inplace=True)
Bitcoin
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2021-01-02  29039.00  33300.00  29413.29  32225.91  46675.246521
# 2021-01-03  32008.62  34810.00  32222.88  33080.66  36951.716506
# 2021-01-04  27678.00  33666.99  33082.84  32019.99  46045.389685
# 2021-01-05  29891.13  34499.67  32020.22  34030.64  42282.569200
# 2021-01-06  33352.54  37000.00  34043.91  36859.26  45744.103200
# ...              ...       ...       ...       ...           ...
# 2021-10-03  47120.11  49300.00  47663.74  48233.99   7989.259259
# 2021-10-04  46916.70  49505.00  48233.99  49245.54  13938.641830
# 2021-10-05  49057.18  51906.23  49244.13  51493.99  17828.597267
# 2021-10-06  50416.01  55757.11  51499.77  55339.48  25869.649260
# 2021-10-07  53379.00  55356.85  55346.95  53797.82  15820.834176
#
# [279 rows x 5 columns]

# %%
tickers=["Bitcoin","Cardano"]

# %%
Cardano = pd.DataFrame(c.get_product_historic_rates('ADA-USD', start = '2021-01-01T01:00:00', end = '2021-10-07T01:00:00' , granularity = 86400))
Cardano.columns= ["Date","Open","High","Low","Close","Volume"]
Cardano['Date'] = pd.to_datetime(Cardano['Date'], unit='s')
Cardano.set_index('Date', inplace=True)
Cardano.sort_values(by='Date', ascending=True, inplace=True)
Cardano
# Out:
#               Open    High     Low   Close        Volume
# Date
# 2021-03-18  1.2155  1.8800  1.6551  1.2300  1.123849e+08
# 2021-03-19  1.1808  1.3960  1.2311  1.3076  1.666585e+08
# 2021-03-20  1.2001  1.3450  1.3065  1.2013  1.214420e+08
# 2021-03-21  1.1607  1.2463  1.2013  1.1885  5.559264e+07
# 2021-03-22  1.0700  1.2076  1.1885  1.1027  8.024998e+07
# ...            ...     ...     ...     ...           ...
# 2021-10-03  2.2224  2.3093  2.2485  2.2531  5.356730e+07
# 2021-10-04  2.1502  2.2545  2.2529  2.1915  7.315132e+07
# 2021-10-05  2.1778  2.2589  2.1922  2.2331  7.068145e+07
# 2021-10-06  2.1137  2.2500  2.2339  2.2107  1.155512e+08
# 2021-10-07  2.1510  2.3749  2.2111  2.2783  1.319050e+08
#
# [204 rows x 5 columns]

# %%
df_concat = pd.concat([Bitcoin, Cardano], axis=1, keys=["Bitcoin","Cardano"], join="inner")

df_concat
# Out:
#              Bitcoin                                             Cardano  \
#                 Open      High       Low     Close        Volume    Open
# Date
# 2021-03-18  56996.15  60100.00  58925.54  57644.95  21459.496240  1.2155
# 2021-03-19  56260.00  59461.99  57644.95  58039.66  16429.629743  1.1808
# 2021-03-20  57827.97  59928.00  58026.91  58116.70   9725.281237  1.2001
# 2021-03-21  55543.89  58651.22  58126.34  57363.32  11841.638779  1.1607
# 2021-03-22  53739.50  58421.68  57377.29  54110.07  19512.156472  1.0700
# ...              ...       ...       ...       ...           ...     ...
# 2021-10-03  47120.11  49300.00  47663.74  48233.99   7989.259259  2.2224
# 2021-10-04  46916.70  49505.00  48233.99  49245.54  13938.641830  2.1502
# 2021-10-05  49057.18  51906.23  49244.13  51493.99  17828.597267  2.1778
# 2021-10-06  50416.01  55757.11  51499.77  55339.48  25869.649260  2.1137
# 2021-10-07  53379.00  55356.85  55346.95  53797.82  15820.834176  2.1510
#
#
#               High     Low   Close        Volume
# Date
# 2021-03-18  1.8800  1.6551  1.2300  1.123849e+08
# 2021-03-19  1.3960  1.2311  1.3076  1.666585e+08
# 2021-03-20  1.3450  1.3065  1.2013  1.214420e+08
# 2021-03-21  1.2463  1.2013  1.1885  5.559264e+07
# 2021-03-22  1.2076  1.1885  1.1027  8.024998e+07
# ...            ...     ...     ...           ...
# 2021-10-03  2.3093  2.2485  2.2531  5.356730e+07
# 2021-10-04  2.2545  2.2529  2.1915  7.315132e+07
# 2021-10-05  2.2589  2.1922  2.2331  7.068145e+07
# 2021-10-06  2.2500  2.2339  2.2107  1.155512e+08
# 2021-10-07  2.3749  2.2111  2.2783  1.319050e+08
#
# [204 rows x 10 columns]

# %%
# Import the MCSimulation module from the MCForecastTools library file
from MCForecastTools import MCSimulation

# %%
MC_even_weight = MCSimulation(
    portfolio_data = df_concat,
    weights= [0.50,0.50],
    num_simulation = 500 ,
    num_trading_days = 3*364
)

MC_even_weight.portfolio_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-81bc67648222> in <module>
#       3     weights= [0.50,0.50],
#       4     num_simulation = 500 ,
# ----> 5     num_trading_days = 3*364
#       6 )
#       7
#
# ~\Desktop\FinTech-WorkingSpace\Project_1\Test_Peoject_1\MCForecastTools.py in __init__(self, portfolio_data, weights, num_simulation, num_trading_days)
#      60         # Calculate daily return if not within dataframe
#      61         if not "daily_return" in portfolio_data.columns.get_level_values(1).unique():
# ---> 62             Close_df = portfolio_data.xs('Close',level=1,axis=1).pct_change()
#      63             tickers = portfolio_data.columns.get_level_values(0).unique()
#      64             column_names = [(x,"daily_return") for x in tickers]
#
# ~\Anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3709             if not isinstance(labels, MultiIndex):
#    3710                 raise TypeError("Index must be a MultiIndex")
# -> 3711             loc, new_ax = labels.get_loc_level(key, level=level, drop_level=drop_level)
#    3712
#    3713             # create the tuple of the indexer
#
# ~\Anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\multi.py in get_loc_level(self, key, level, drop_level)
#    2963         else:
#    2964             level = [self._get_level_number(lev) for lev in level]
# -> 2965         return self._get_loc_level(key, level=level, drop_level=drop_level)
#    2966
#    2967     def _get_loc_level(
#
# ~\Anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_level(self, key, level, drop_level)
#    3066                 return indexer, maybe_mi_droplevels(indexer, ilevels, drop_level)
#    3067         else:
# -> 3068             indexer = self._get_level_indexer(key, level=level)
#    3069             return indexer, maybe_mi_droplevels(indexer, [level], drop_level)
#    3070
#
# ~\Anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    3156         else:
#    3157
# -> 3158             idx = self._get_loc_single_level_index(level_index, key)
#    3159
#    3160             if level > 0 or self.lexsort_depth == 0:
#
# ~\Anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_single_level_index(self, level_index, key)
#    2807             return -1
#    2808         else:
# -> 2809             return level_index.get_loc(key)
#    2810
#    2811     def get_loc(self, key, method=None):
#
# ~\Anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'close'

# %% [raw]
# The above code does not work. If we can run the simulation, will need to calculate the cumulative return on all the simulated trade rates and from there, make a statistical summary results table  with upper and lowe 95% (or 99%) interval statistics. Thus from there, we can inform the client about her expected profit with 95% (or 99%) confidence.
